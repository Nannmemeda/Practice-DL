# %%
from fastbook import *

# %%
# !pip install -Uqq fastai duckduckgo_search

# %%
from  duckduckgo_search import DDGS

# %% [markdown]
# Step 1: Download images of birds and non-birds

# %%
from duckduckgo_search import *
from fastcore.all import *

def search_images(term, max_images=30):
    print(f"Searching for '{term}' ")
    with DDGS() as ddgs:
        keywords = term
        return L(ddgs.images(term, max_results=max_images, license_image='ShareCommercially')).itemgot('image')

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# Searching for 'bird photos'
# /var/folders/t3/ctmyp9cd5j7ctjhqp2_g843h0000gn/T/ipykernel_14176/2654051221.py:6: UserWarning: DDGS running in an async loop. This may cause errors. Use AsyncDDGS instead.
#   with DDGS() as ddgs:
# 'https://upload.wikimedia.org/wikipedia/commons/6/67/Mockingbird,_Northern_SunsetBeach.jpg'

# %%
from fastdownload import download_url
dest = 'bird.jpy'
download_url(urls[0],dest,show_progress = False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x192>

# %%
download_url(search_images('forest photos',max_images=1)[0], 'forest.jpg',show_progress=False)
Image.open('forest.jpg').to_thumb(256,256)
# Out:
# Searching for 'forest photos'
# /var/folders/t3/ctmyp9cd5j7ctjhqp2_g843h0000gn/T/ipykernel_14176/2654051221.py:6: UserWarning: DDGS running in an async loop. This may cause errors. Use AsyncDDGS instead.
#   with DDGS() as ddgs:
# <PIL.Image.Image image mode=RGB size=256x171>
